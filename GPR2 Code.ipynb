# %%
import pandas as pd
file_path = 'MSCI_data.csv'
datafile = pd.read_csv(file_path)
datafile.head()
# Out:
#             Date              Index  Price  Size  Momentum  Value  Beta  \
# 0  March 30 2024        MSCI Canada    100    10         1     10   0.9
# 1  March 30 2024           MSCI USA    200   250         2     10   1.0
# 2  March 30 2024            MSCI UK    300    50         5     11   1.2
# 3  March 30 2024         MSCI China    400   300         3      9   1.9
# 4  March 30 2024  MSCI South Africa    500    20         1     12   0.7
#
#    Return_M
# 0      1.05
# 1      0.94
# 2      1.03
# 3      0.88
# 4      1.21
